# %%
from os import path
import numpy as np
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
import matplotlib.pyplot as plt
from bentdna.regression import RegressAgent, SixPlots
workfolder = '/home/yizaochen/codes/dna_rna/length_effect/find_helical_axis'

# %% [markdown]
# ### Part 1: Initialize

# %%
host = 'a_tract_21mer'
r_agent = RegressAgent(host, workfolder)
# Out:
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/a_tract_21mer/an_folder exists

# %% [markdown]
# ### Part 2: First plot to observe

# %%
fig, axes = r_agent.draw_observe_plot()
plt.show()

# %% [markdown]
# ### Part 5: Do regression, for $y=ax$, where $x=(\frac{1}{n})^2$

# %%
select_nlist = [2, 3, 4] # Ad hoc

# %%
r_agent.do_regression(select_nlist)
# Out:
# Coefficients: 0.031
# Mean squared error: 0.000
# Coefficient of determination: 0.33

# %%
fig, ax = r_agent.draw_regr_var_an_nsquare_inverse(select_nlist)
plt.show()

# %% [markdown]
# ### Part 6: After fitting, Var($a_n$) vs $n$

# %%
fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8,4))
r_agent.draw_regr_var_an_n(ax, select_nlist)
plt.show()

# %% [markdown]
# ### Part 7: Batch

# %%
figsize = (6.6, 3)
markersize = 4
ylim = (-0.001, 0.045)
plot_agent = SixPlots(figsize, markersize, ylim, xratio=64, yratio=85)
plot_agent.plot_main()
plt.tight_layout()
#plt.savefig('quadratic_fitting.svg')
plt.show()
# Out:
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/a_tract_21mer/an_folder exists
# Coefficients: 0.031
# Mean squared error: 0.000
# Coefficient of determination: 0.33
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/atat_21mer/an_folder exists
# Coefficients: 0.042
# Mean squared error: 0.000
# Coefficient of determination: 0.39
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/ctct_21mer/an_folder exists
# Coefficients: 0.042
# Mean squared error: 0.000
# Coefficient of determination: 0.08
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/g_tract_21mer/an_folder exists
# Coefficients: 0.047
# Mean squared error: 0.000
# Coefficient of determination: -0.11
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/gcgc_21mer/an_folder exists
# Coefficients: 0.034
# Mean squared error: 0.000
# Coefficient of determination: 0.21
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/tgtg_21mer/an_folder exists
# ...

# %% [markdown]
# #### Reference:
# - https://towardsdatascience.com/polynomial-regression-bbe8b9d97491
# - https://stackoverflow.com/questions/34373606/scikit-learn-coefficients-polynomialfeatures
# - https://scikit-learn.org/stable/auto_examples/linear_model/plot_ols.html
