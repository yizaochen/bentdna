# %%
from os import path
import numpy as np
from matplotlib import rcParams
rcParams['font.family'] = 'sans-serif'
rcParams['font.sans-serif'] = ['Arial']
import matplotlib.pyplot as plt
from bentdna.shapefourier import AvgShapeSixPlots

# %% [markdown]
# ### Part 0: Initialize

# %%
figsize = (6.6, 3)
agent = AvgShapeSixPlots(figsize)

# %% [markdown]
# ### Part 1: Make Dataframe(if need)

# %%
#df = agent.make_dataframe()
df = agent.read_dataframe()
df
# Out:
#     Unnamed: 0  a_tract_21mer  atat_21mer  ctct_21mer  g_tract_21mer  \
# 0            0       0.000000    0.000000    0.000000       0.000000
# 1            1       0.071581    0.093377    0.073111       0.078833
# 2            2       0.107927    0.122777    0.126180       0.134511
# 3            3       0.145525    0.168719    0.182975       0.186364
# 4            4       0.174285    0.199195    0.217322       0.224008
# 5            5       0.198109    0.230532    0.250256       0.251691
# 6            6       0.216671    0.247554    0.262825       0.272794
# 7            7       0.231818    0.269646    0.278929       0.286719
# 8            8       0.244290    0.284147    0.283770       0.295198
# 9            9       0.255859    0.305832    0.295677       0.303860
# 10          10       0.267898    0.319772    0.304065       0.317268
# 11          11       0.282631    0.339193    0.321376       0.332093
# 12          12       0.300277    0.353825    0.333876       0.350567
# ...

# %% [markdown]
# ### Part 2: Plot

# %%
fig, ax = agent.plot_main()
plt.tight_layout()
plt.savefig('average_theta.svg')
plt.show()

# %% [markdown]
# ### Part 3: Get $\theta^0(\textbf{r}_{18})$

# %%
agent.get_theta0_r18_radian()
# Out:
# a_tract_21mer: 0.311
# atat_21mer: 0.373
# ctct_21mer: 0.353
# g_tract_21mer: 0.367
# gcgc_21mer: 0.350
# tgtg_21mer: 0.363

# %%
agent.get_theta0_r18_degree()
# Out:
# a_tract_21mer: 17.8
# atat_21mer: 21.4
# ctct_21mer: 20.2
# g_tract_21mer: 21.0
# gcgc_21mer: 20.1
# tgtg_21mer: 20.8

# %% [markdown]
# ### Part 3: Big size

# %%
figsize = (16, 6)
agent = AvgShapeSixPlots(figsize)

# %%
fig, ax = agent.plot_main()
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Addtional Part: Six plots together

# %%
fig, d_axes = agent.plot_six_plots()
plt.tight_layout()
plt.show()
