# %%
from os import path
import numpy as np
import matplotlib.pyplot as plt
from bentdna import shapefourier
workfolder = '/home/yizaochen/codes/dna_rna/length_effect/find_helical_axis'

# %% [markdown]
# ### Part 1: Initialize

# %%
hosts = ['a_tract_21mer', 'ctct_21mer', 'gcgc_21mer', 'g_tract_21mer', 'atat_21mer', 'tgtg_21mer']
group1 = ['a_tract_21mer', 'ctct_21mer', 'gcgc_21mer']
group2 = ['g_tract_21mer', 'atat_21mer', 'tgtg_21mer']
colors = ['b', 'g', 'r', 'c', 'm', 'y']
xticklabels = ['AA', 'CTCT', 'GCGC', 'GG', 'ATAT', 'TGTG']

# %%
d_df = dict()
for host in hosts:
    s_agent = shapefourier.ShapeAgent(workfolder, host)
    d_df[host] = s_agent.read_df_an(n_begin, n_end)
# Out:
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/a_tract_21mer/an_folder exists
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/ctct_21mer/an_folder exists
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/gcgc_21mer/an_folder exists
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/g_tract_21mer/an_folder exists
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/atat_21mer/an_folder exists
# /home/yizaochen/codes/dna_rna/length_effect/find_helical_axis/tgtg_21mer/an_folder exists

# %% [markdown]
# ### Part 3: Read DataFrame of $a_n$

# %%
# read
n_begin = 0
n_end = 9
df_an = s_agent.read_df_an(n_begin, n_end)

# %%
df_an
# Out:
#              0         1         2         3         4         5         6  \
# 0     0.787333 -0.261824  0.043888 -0.034394 -0.045819  0.005541 -0.061191
# 1     0.649107 -0.290023 -0.002105  0.071747  0.061809  0.015253 -0.039059
# 2     0.577889  0.019757 -0.093318 -0.092551  0.052463 -0.015203 -0.052352
# 3     0.525947 -0.024198  0.012524 -0.034565  0.028548 -0.049440 -0.052760
# 4     0.527048 -0.223556  0.090574  0.033560 -0.035235 -0.023682 -0.036500
# ...        ...       ...       ...       ...       ...       ...       ...
# 9995  0.529102 -0.125061  0.054868 -0.090148 -0.061074  0.053567 -0.035616
# 9996  0.427554 -0.020823  0.031817 -0.123465 -0.047093  0.035558  0.028426
# 9997  0.632501 -0.174720  0.122089 -0.082154 -0.032170  0.046099 -0.046826
# 9998  0.312436 -0.009179  0.087486 -0.028034  0.028924 -0.033178  0.009166
# 9999  0.500922 -0.174034  0.136362 -0.067754  0.034677  0.052432 -0.041247
#
#              7         8         9
# ...

# %% [markdown]
# ### Part : Box Plot

# %%
fig, axes = plt.subplots(ncols=5, nrows=2, figsize=(24,8))

n = 0
for row_id in range(2):
    for col_id in range(5):
        if (row_id == 1) and (col_id == 4):
            ax = axes[row_id, col_id]
            ax.set_axis_off()
            continue
        ax = axes[row_id, col_id]
        key = str(n)
        x = list()
        for host in hosts:
            x.append(d_df[host][key])
        ax.boxplot(x)
        ax.set_xticklabels(xticklabels)
        ax.set_ylabel(r'$a_{' + f'{n}' + r'}$', fontsize=14)
        ax.tick_params(axis='x', labelsize=12)
        n += 1
plt.tight_layout()
#plt.savefig("an_boxplot.png", dpi=200)
plt.show()

# %%
n = 0
key = str(n)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4), sharex=True)
x = list()
for host in hosts:
    x.append(d_df[host][key])
ax.boxplot(x)
ax.set_xticklabels(hosts)
ax.set_ylabel(r'$a_{' + f'{n}' + r'}$', fontsize=14)

plt.show()

# %%
n = 1
key = str(n)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4), sharex=True)
x = list()
for host in hosts:
    x.append(d_df[host][key])
ax.boxplot(x)
ax.set_xticklabels(hosts)
ax.set_ylabel(r'$a_{' + f'{n}' + r'}$', fontsize=14)

plt.show()

# %%
n = 2
key = str(n)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4), sharex=True)
x = list()
for host in hosts:
    x.append(d_df[host][key])
ax.boxplot(x)
ax.set_xticklabels(hosts)
ax.set_ylabel(r'$a_{' + f'{n}' + r'}$', fontsize=14)

plt.show()

# %%
n = 3
key = str(n)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4), sharex=True)
x = list()
for host in hosts:
    x.append(d_df[host][key])
ax.boxplot(x)
ax.set_xticklabels(hosts)b
ax.set_ylabel(r'$a_{' + f'{n}' + r'}$', fontsize=14)

plt.show()

# %%
n = 4
key = str(n)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4), sharex=True)
x = list()
for host in hosts:
    x.append(d_df[host][key])
ax.boxplot(x)
ax.set_xticklabels(hosts)
ax.set_ylabel(r'$a_{' + f'{n}' + r'}$', fontsize=14)

plt.show()

# %%
n = 5
key = str(n)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4), sharex=True)
x = list()
for host in hosts:
    x.append(d_df[host][key])
ax.boxplot(x)
ax.set_xticklabels(hosts)
ax.set_ylabel(r'$a_{' + f'{n}' + r'}$', fontsize=14)

plt.show()

# %%
n = 6
key = str(n)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4), sharex=True)
x = list()
for host in hosts:
    x.append(d_df[host][key])
ax.boxplot(x)
ax.set_xticklabels(hosts)
ax.set_ylabel(r'$a_{' + f'{n}' + r'}$', fontsize=14)

plt.show()

# %%
n = 7
key = str(n)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4), sharex=True)
x = list()
for host in hosts:
    x.append(d_df[host][key])
ax.boxplot(x)
ax.set_xticklabels(hosts)
ax.set_ylabel(r'$a_{' + f'{n}' + r'}$', fontsize=14)

plt.show()

# %%
n = 8
key = str(n)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4), sharex=True)
x = list()
for host in hosts:
    x.append(d_df[host][key])
ax.boxplot(x)
ax.set_xticklabels(hosts)
ax.set_ylabel(r'$a_{' + f'{n}' + r'}$', fontsize=14)

plt.show()

# %%
n = 9
key = str(n)
fig, ax = plt.subplots(ncols=1, nrows=1, figsize=(8,4), sharex=True)
x = list()
for host in hosts:
    x.append(d_df[host][key])
ax.boxplot(x)
ax.set_xticklabels(hosts)
ax.set_ylabel(r'$a_{' + f'{n}' + r'}$', fontsize=14)

plt.show()

# %% [markdown]
# ### Part 4: Histogram

# %%
n = 0
key = str(n)

fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(8,4), sharex=True)
colorid = 0
ax = axes[0]
for host in group1:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

ax = axes[1]
for host in group2:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

plt.show()

# %%
n = 1
key = str(n)

fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(8,4), sharex=True)
colorid = 0
ax = axes[0]
for host in group1:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

ax = axes[1]
for host in group2:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

plt.show()

# %%
n = 2
key = str(n)

fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(8,4), sharex=True)
colorid = 0
ax = axes[0]
for host in group1:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

ax = axes[1]
for host in group2:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

plt.show()

# %%
n = 3
key = str(n)

fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(8,4), sharex=True)
colorid = 0
ax = axes[0]
for host in group1:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

ax = axes[1]
for host in group2:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

plt.show()

# %%
n = 4
key = str(n)

fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(8,4), sharex=True)
colorid = 0
ax = axes[0]
for host in group1:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

ax = axes[1]
for host in group2:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

plt.show()

# %%
n = 5
key = str(n)

fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(8,4), sharex=True)
colorid = 0
ax = axes[0]
for host in group1:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

ax = axes[1]
for host in group2:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

plt.show()

# %%
n = 6
key = str(n)

fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(8,4), sharex=True)
colorid = 0
ax = axes[0]
for host in group1:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

ax = axes[1]
for host in group2:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

plt.show()

# %%
n = 7
key = str(n)

fig, axes = plt.subplots(ncols=2, nrows=1, figsize=(8,4), sharex=True)
colorid = 0
ax = axes[0]
for host in group1:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

ax = axes[1]
for host in group2:
    x = d_df[host][key]
    ax.hist(x, bins=50, alpha=0.5, label=host, color=colors[colorid])
    colorid += 1
ax.legend()

plt.show()
